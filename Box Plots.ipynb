# %% [markdown]
#  # An Investigation into Box Plots
#
# The purpose of this Jupyter Notebook is to investigate and explain box plots and their uses. To help explain box plots, I will be using th eboxplot function from the Python package matplotlib.pyplot. I will undertake this task by:
#
# - Summarising the history of the box plot and situations in which it used.
# - Demonstrating the use of the box plot using data
# - Explaining the box plot terminology
# - Comparing the box plot to alternative plots

# %% [markdown]
# https://en.wikipedia.org/wiki/John_Tukey#/media/File:John_Tukey.jpg
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # The Boxplot
#
# John Wilder Tukey (June 16, 1915 – July 26, 2000) was an American mathematician best known for development of the boxplot.  He introduced the box and whiskers plot as part of his toolkit for exploratory data analysis (Tukey,
# 1970), but it did not become widely known until formal publication in 1977.
#
# The boxplot has become one of the most frequently used statistical graphics, and is one of the few plot types invented in the 20th century that has found widespread adoption. Due to  their elegance and practicality, boxplots have spawned a wealth of variations and enhancement. (ref: http://vita.had.co.nz/papers/boxplots.pdf).
#
# In researching this project, I found a very interesting paper by Hadley Wickham and Lisa Stryjewski, titled '40 Years of Box Plots'.  The authors summarise the improvements, extensions and variations since Tukey first introduced his “schematic plot” in 1970, with particular focus on richer displays of density and extensions to 2d.  The keys findings of this paper are:
#
# - Boxplots were created to provide a distributional summary that could easily be created by hand and supported comparison across groups. As computers have become more prevalent and more powerful, it has become easier to produce compact summaries that display more data. This has led to an explosion of boxplot variations that stay true to the original goals to various extents, while supporting much richer display of the underlying distributions.
#
#
# - Richer displays of density: The first variation to display a density estimate was the Vase plot (Benjamini, 1988), where the box is replaced with a symmetrical display of estimated density. Violin plots, the Bean plot (Kampstra, 2008), the Raindrop plot (Barrowman and Myers, 2003) are all variations of the Box Plot that show richer display of density.
#
#
# - Extending the boxplot to work in 2d is challenging because of the difficulty of defining order statistics, depth and quantiles in 2d. There is no unique definition of rank in 2d dimensions, and hence the 2d analogues of medians, fourths and extremes becomes more complex (mathematically and computationally).  Perhaps due to the increased complexity of creating just a single plot, there has been little development of effective methods for comparing multiple groups.  The Rangefinder plot (Becketti and Gould, 1987), the Bagplot, (Rousseuw et al., 1999), Functional boxplots (Hyndman and Shang, 2010; Sun and Genton, 2011) are a few examples of 2d boxplots.

# %% [markdown]
# # What is a Box Plot
#
# Simply put, a box plot is a way of representing statistical data on a plot in which a rectangle is drawn to represent the second and third quartiles, usually with a vertical line inside to indicate the median value. The lower and upper quartiles are shown as horizontal lines either side of the rectangle.  Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram. (ref: https://en.wikipedia.org/wiki/Box_plot).
#
# A boxplot powerfully depicts the centers and spreads of given data. The two most important measures of center are the mean and the median. Important measures of spread include the interquartile range and the mean absolute deviation.
#
# Box plots are non-parametric: they display variation in samples of a statistical population without making any assumptions of the underlying statistical distribution. The spacings between the different parts of the box indicate the degree of dispersion (spread) and skewness in the data, and show outliers. Box plots can be drawn either horizontally or vertically. Box plots received their name from the box in the middle.
#
# A Box Plot is the visual representation of the statistical five number summary of a given data set.  A Five Number Summary includes:
#
# - Minimum
# - First Quartile
# - Median (Second Quartile)
# - Third Quartile
# - Maximum
#
# The box plot allows quick graphical examination of one or more data sets and are useful for comparing distributions between several groups or sets of data.
#
# A boxplot is a standardized way of displaying the distribution of data based on the above five number summary. It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.
#
# In summary, Box plots are very effective and easy to read. They summarize data from multiple sources and display the results in a single graph. Box plots allow for comparison of data from different categories for easier, more effective decision-making.

# %% [markdown]
# # The Boxplot Explained
# (ref: https://chartio.com/resources/tutorials/what-is-a-box-plot)

# %% [markdown]
# ![Box%20Chart%20Explained.PNG](attachment:Box%20Chart%20Explained.PNG)

# %% [markdown]
# # When to use a Box plot
#
# You use a box plot when you have multiple data sets from independent sources that are related to each other in some way.  The box plot is suitable for comparing range and distribution for groups of numerical data. For example:
#
# - exam results between schools or classes
# - data from before and after a process change
# - data from duplicate machines manufacturing the same products
#
# A disadvantage of the box plot is that it is not relevant for detailed analysis of data as it deals with a summary of the data distribution.

# %% [markdown]
# The Box Plot is especially useful for indicating whether a distribution is skewed and whether there are potential unusual observations (outliers) in the data set. Box plots are also very useful when large numbers of observations are involved and when two or more data sets are being compared.
#
# A box plot is a way of summarizing a set of data measured on an interval scale. It is often used in explanatory data analysis. This type of graph is used to show the shape of the distribution, its central value, and its variability.

# %% [markdown]
# # An Example of the Box Plot

# %% [markdown]
# An example of a Box plot (ref: https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py).  To understand how to plot the simple Box Plot I have studied the matplotlib documentation

# %%
#importing numpy to generate random data and matplotlib to display the data in a box plot
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))
                      
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x140e6b2f278>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x140e6b2fb38>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x140e6b2f128>],
#  'medians': [<matplotlib.lines.Line2D at 0x140e6b3f3c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x140e6b3f7f0>],
#  'means': []}

# %% [markdown]
# ## Explanation of the Matplotlib.pyplot example
#
# Make a box and whisker plot for each column of x or each vector in sequence x. The box extends from the lower to upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data. Flier points are those past the end of the whiskers. (ref: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html)
#
# Lets explain the above example from matplotlip:
#
# - spread = np.random.rand(50) * 100                 #the spread of the data
#
#
# - center = np.ones(25) * 50                         #the mean
#
#
# - flier_high = np.random.rand(10) * 100 + 100       #the data range goes up to 200
#
#
# - flier_low = np.random.rand(10) * -100             #the data range goes down to -100
#
#
# - data = np.concatenate((spread, center, flier_high, flier_low))  #NumPy’s concatenate function can be used to concatenate two arrays either row-wise or column-wise. Concatenate function can take two or more arrays of the same shape and by default it concatenates row-wise

# %% [markdown]
# # Generate Box Plot
#
# To fully understand the matplotlib.pyplot function, I think it best to generate my own boxplot.  I will mock up 4 x dataframes and test the various matplotlib functions.

# %% [markdown]
# ### The Standard Box Plot

# %%
# Mock up 4 x dataframes

df1=[82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
df2=[62,5,91,25,36,32,96,95,3,90,95,32,27,55,100,15,71,11,37,21]
df3=[23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
df4=[59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot
dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x') # gives a title to the x axis
t = plt.title('Box plot') #give a title to the plot
plt.boxplot(dataframes) # plots the dataframes as a box plot using matplotlib
plt.show() # displays the box plot

# %% [markdown]
# ### The Notched Box Plot

# %%
# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot

dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x')
t = plt.title('Box plot')
plt.boxplot(dataframes, notch = True) # If True, will produce a notched box plot. Otherwise, a rectangular boxplot is produced.
plt.show()

# %% [markdown]
# ### Formatting the Markers differently

# %%
# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot
dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x')
t = plt.title('Box plot')
green_diamond = dict(markerfacecolor='g', marker='D') #changes the markers from circles to green diamonds
plt.boxplot(dataframes, flierprops=green_diamond)
plt.show()

# %% [markdown]
# ### Adding Colour

# %%
# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot
dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x') # gives a title to the x axis
t = plt.title('Box plot') #give a title to the plots  
plt.boxplot(dataframes, patch_artist=True) # adds colour to the rectangles
plt.show() # displays the box plot

# %% [markdown]
# ## The Importance of the Shape of a Box Plot
#
# To show how box plots change shape when the underlying properties of the variables change, I will relook at the standard box plot I created using mocked up data frames

# %%
# mock up a dataframe

df1=[82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]

plt.xlabel('measurement x') # gives a title to the x axis
t = plt.title('Box plot') #give a title to the plot
plt.boxplot(df1) # plots the dataframe as a box plot using matplotlib
plt.show() # displays the box plot

# %%
# 1 have changed 6 variables in the dataframe displayed above and renamed the dataframe df2
# compare df1 boxplot to df2 boxplot

df2=[200,250,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,10,8,5]
dataframes=[df1, df2]
plt.xlabel('measurement x') # gives a title to the x axis
t = plt.title('Box plot') #give a title to the plot
plt.boxplot(dataframes) # plots the dataframe as a box plot using matplotlib
plt.show() # displays the box plot

# %% [markdown]
# ## Key Changes
# - The outliers in df2 have dramtically altered where the median falls within the interquartile range
# - What are considered outliers in df1, are not longer outliers in df2

# %%
# 1 have changed 8 variables in the dataframe df1 and renamed the dataframe df3
# compare df1 boxplot to df3 boxplot

df3=[200,250,225,195,180,62,75,78,71,32,98,89,78,67,72,82,87,86,95,90]
dataframes=[df1, df3]
plt.xlabel('measurement x') # gives a title to the x axis
t = plt.title('Box plot') #give a title to the plot
plt.boxplot(dataframes) # plots the dataframe as a box plot using matplotlib
plt.show() # displays the box plot

# %% [markdown]
# ## Key Changes
# - With the spread of data now including larger numbers, it is clear to see the median has moved
# - The shape of the interquartile range has changed

# %% [markdown]
# ## Box Plots are the ideal visualization tool when comparing the spread of data

# %% [markdown]
# # Further Investigation into Box Plots with Matplotlib & the Iris Data Set
# Being familiar with the Iris dataset, I feel is it an ideal data set to use to generate box plots

# %%
#ref: https://github.com/ClaireDrummond/GMITProject2018

import pandas # library for statistics in data anaylsis

# Load dataset from UCI Machine Learning repository - new learning iris_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
dataset = pandas.read_csv(url, names=names)

# shape - this tells quantity of rows and columns in the dataset
print(dataset.shape)

# head - prints first ten rows of the dataset
print(dataset.head(10))

# description - prints keys stats on the dataset
print(dataset.describe())
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# ...

# %%
dataset.columns # Column Names
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
plt.boxplot(dataset.sepal_length) # box plot of Sepal Length
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x140e6cfa710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x140e6cfa160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x140e6cfaf28>],
#  'medians': [<matplotlib.lines.Line2D at 0x140e6b72c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x140e6c674a8>],
#  'means': []}

# %%
plt.boxplot(dataset.sepal_width) # box plot of sepal width
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x140e6d6f160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x140e6bae240>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x140e6d6f9b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x140e6baea90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x140e6baeeb8>],
#  'means': []}

# %%
plt.boxplot(dataset.petal_length) #box plot of petal length
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x140e6ca89b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x140e6c852b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x140e6ca8860>],
#  'medians': [<matplotlib.lines.Line2D at 0x140e6c85b00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x140e6c85f28>],
#  'means': []}

# %%
plt.boxplot(dataset.petal_width) # box plot of petal width
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x140e6c6a9b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x140e6dbd2b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x140e6c6a860>],
#  'medians': [<matplotlib.lines.Line2D at 0x140e6dbdb00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x140e6dbdf28>],
#  'means': []}

# %%
# generate the 4 boxplots together in one line of code
# ref:https://matplotlib.org/gallery/recipes/create_subplots.html
dataset.plot(kind='box', patch_artist=True, subplots=True, layout=(2,2), sharex=False, sharey=False) 
plt.show()

# %% [markdown]
# # Terminology
#
# Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
#
# - median (Q2/50th Percentile): the middle value of the dataset.
#
#
# - first quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.
#
#
# - third quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.
#
#
# - interquartile range (IQR): 25th to the 75th percentile.
#
#
# - whiskers (shown in blue)
#
#
# - outliers (shown as green circles)
#
#
# - “maximum”: Q3 + 1.5*IQR
#
#
# - “minimum”: Q1 -1.5*IQR

# %% [markdown]
# ![Terminology.PNG](attachment:Terminology.PNG)

# %% [markdown]
# #### above diagram ref: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %% [markdown]
# Box plots are the examintation of the distributional characteristics of a group of scores as well as the level of the scores.
#
# The scores are sorted. Then four equal sized groups are made from the ordered scores. That is, 25% of all scores are placed in each group. The lines dividing the groups are called quartiles, and the groups are referred to as quartile groups. Usually we label these groups 1 to 4 starting at the bottom.
#
# ## Median
# The median (middle quartile) marks the mid-point of the data and is shown by the line that divides the box into two parts. Half the scores are greater than or equal to this value and half are less.
#
# ## Inter-quartile range
# The middle “box” represents the middle 50% of scores for the group. The range of scores from lower to upper quartile is referred to as the inter-quartile range. The middle 50% of scores fall within the inter-quartile range.
#
# ## Upper quartile
# Seventy-five percent of the scores fall below the upper quartile.
#
# ## Lower quartile
# Twenty-five percent of scores fall below the lower quartile.
#
# ## Whiskers
# The upper and lower whiskers represent scores outside the middle 50%. Whiskers often (but not always) stretch over a wider range of scores than the middle quartile groups

# %% [markdown]
# # Interpreting Box Plots
#
# - Box plots are used to show overall patterns of response for a group. They provide a useful way to visualise the range and other characteristics of responses for a large group.
#
#
# - When the box plot is comparatively short –  This suggests that the overall group have a high level of agreement with each other.
#
#
# - When the box plot is comparatively tall – This suggests the group hold quite different opinions/views/results
#
#
# - When comparing box plots and one box plot is much higher or lower than another  - This could suggest a difference between groups. For example, the box plot for boys may be lower or higher than the equivalent plot for girls.
#
#
# - When comparing box plots and there are obvious differences between box plots – any obvious difference between box plots for comparative groups is worthy of further investigation.
#
#
# - When comparing box plots and there is same median, different distribution – The medians (which generally will be close to the average) are all at the same level. It always important to consider the pattern of the whole distribution of responses in a box plot.

# %% [markdown]
# ## Interpreting the Box Plots of the Iris Data Set
# Visualises the spread the datasets.
#
# - Sepal length and sepal width seem to spread evenly about their own centers
# - Petal lengths and petal widths’ values are more spread below values lower than the average value

# %% [markdown]
# # Comparing the Box Plot to alternative Plots
#
# ## Box Plot v's Histogram
# A histogram presents numeric data and its distribution.  It is a type of bar chart that graphically displays the frequencies of a data set. Both charts effectively represent different data sets; however, in certain situations, one chart may be superior to the other in achieving the goal of identifying variances among data. The type of plot chosen depends on the type of data collected, rough analysis of data trends, and project goals.
#
# A histogram can tell you about the underlying distribution of the data and whether you can apply certain statistical tests to perform potential improvement opportunities. It shows if the variability in the data is within specification limits and if the process is capable or not. It is also used to identify shifts in the process and to verify that the changes you made were a real improvement (ref: https://citoolkit.com/articles/histograms-and-boxplots/)
#
# A histogram is preferred plot, over box plot when:
# - describing the distribution of the data
# - wide variances exist among the observed frequencies for a particular data set
# - there is very little variance among the observed frequencies
#
# A box plot is preferred plot, over histrogram when:
# - comparing distributions of difference data sets
# - wanting to see if distribution is symmetrical or skewed and if there are outliers in the data
# - there is moderate variation among the observed frequencies

# %% [markdown]
# ## Box Plot v's Scatter Plot
# Scatter plots are similar to line graphs in that they use horizontal and vertical axes to plot data points. However, they have a very specific purpose. Scatter plots show how much one variable is affected by another. The relationship between two variables is called their correlation .
#
# Scatter plots usually consist of a large body of data. The closer the data points come when plotted to making a straight line, the higher the correlation between the two variables, or the stronger the relationship.
#
# If the data points make a straight line going from the origin out to high x- and y-values, then the variables are said to have a positive correlation . If the line goes from a high-value on the y-axis down to a high-value on the x-axis, the variables have a negative correlation (ref: https://mste.illinois.edu/courses/ci330ms/youtsey/scatterinfo.html)
#
# Box Plots do not display this relationship between variables.

# %% [markdown]
# # References
# - https://en.wikipedia.org/wiki/Box_plot
# - https://chartio.com/resources/tutorials/what-is-a-box-plot/
# - https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py
# - https://github.com/ClaireDrummond/GMITProject2018
# - https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot
# - https://matplotlib.org/gallery/recipes/create_subplots.html
# - https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
# - https://citoolkit.com/articles/histograms-and-boxplots/
# - https://mste.illinois.edu/courses/ci330ms/youtsey/scatterinfo.html
# - http://vita.had.co.nz/papers/boxplots.pdf
