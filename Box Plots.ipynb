# %% [markdown]
# # The Boxplot
#
# John Wilder Tukey (June 16, 1915 – July 26, 2000) was an American mathematician best known for development of the boxplot. In descriptive statistics, a box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram. (ref: https://en.wikipedia.org/wiki/Box_plot).   Box plots are non-parametric: they display variation in samples of a statistical population without making any assumptions of the underlying statistical distribution. The spacings between the different parts of the box indicate the degree of dispersion (spread) and skewness in the data, and show outliers. In addition to the points themselves, they allow one to visually estimate various L-estimators, notably the interquartile range, midhinge, range, mid-range, and trimean. Box plots can be drawn either horizontally or vertically. Box plots received their name from the box in the middle.
#
# Simply put, a box plot is a way of representing statistical data on a plot in which a rectangle is drawn to represent the second and third quartiles, usually with a vertical line inside to indicate the median value. The lower and upper quartiles are shown as horizontal lines either side of the rectangle.
#
# A Box Plot is the visual representation of the statistical five number summary of a given data set.  A Five Number Summary includes:
#
# - Minimum
# - First Quartile
# - Median (Second Quartile)
# - Third Quartile
# - Maximum
#
# The box plot allows quick graphical examination of one or more data sets and are useful for comparing distributions between several groups or sets of data.
#
# A boxplot is a standardized way of displaying the distribution of data based on the above five number summary. It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.
#
# In summary, Box plots are very effective and easy to read. They summarize data from multiple sources and display the results in a single graph. Box plots allow for comparison of data from different categories for easier, more effective decision-making.

# %% [markdown]
# # The Boxplot Explained
# (ref: https://chartio.com/resources/tutorials/what-is-a-box-plot)

# %% [markdown]
# ![Box%20Chart%20Explained.PNG](attachment:Box%20Chart%20Explained.PNG)

# %% [markdown]
# # When to use a Box plot
#
# You use a box plot when you have multiple data sets from independent sources that are related to each other in some way.  The box plot is suitable for comparing range and distribution for groups of numerical data. For example:
#
# - exam results between schools or classes
# - data from before and after a process change
# - data from duplicate machines manufacturing the same products
#
# A disadvantage of the box plot is that it is not relevant for detailed analysis of data as it deals with a summary of the data distribution.

# %% [markdown]
# The Box Plot is especially useful for indicating whether a distribution is skewed and whether there are potential unusual observations (outliers) in the data set. Box plots are also very useful when large numbers of observations are involved and when two or more data sets are being compared.
#
# A box plot is a way of summarizing a set of data measured on an interval scale. It is often used in explanatory data analysis. This type of graph is used to show the shape of the distribution, its central value, and its variability.

# %% [markdown]
# # An Example of the Box Plot

# %% [markdown]
# An example of a Box plot (ref: https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py).  To understand how to plot the simple Box Plot I have studied the matplotlib documentation

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))
                      
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bda8525e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bda8530748>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bda8525cf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bda8530f98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bda8538400>],
#  'means': []}

# %% [markdown]
# ## Explanation of the Matplotlib.pyplot example
#
# Make a box and whisker plot for each column of x or each vector in sequence x. The box extends from the lower to upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data. Flier points are those past the end of the whiskers. (ref: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html)
#
# Lets explain the above example from matplotlip:
#
# - spread = np.random.rand(50) * 100                 #the spread of the data
# - center = np.ones(25) * 50                         #the mean
# - flier_high = np.random.rand(10) * 100 + 100       #the data range goes up to 200
# - flier_low = np.random.rand(10) * -100             #the data range goes down to -100
# - data = np.concatenate((spread, center, flier_high, flier_low))  #NumPy’s concatenate function can be used to concatenate two arrays either row-wise or column-wise. Concatenate function can take two or more arrays of the same shape and by default it concatenates row-wise

# %% [markdown]
# # Generate Box Plot
#
# To fully understand the matplotlib.pyplot function, I think it best to generate my own boxplot.

# %%
df1=[82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
df2=[62,5,91,25,36,32,96,95,3,90,95,32,27,55,100,15,71,11,37,21]
df3=[23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
df4=[59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot
dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x') # gives a title to the x axis
t = plt.title('Box plot') #give a title to the plot
plt.boxplot(dataframes) # plots the dataframes as a box plot using matplotlib
plt.show()

# %%
# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot

dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x')
t = plt.title('Box plot')
plt.boxplot(dataframes, notch = True) # displays notch instead of box
plt.show()

# %%
# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html?highlight=boxplot
dataframes=[df1,df2,df3,df4]
plt.xlabel('measurement x')
t = plt.title('Box plot')
green_diamond = dict(markerfacecolor='g', marker='D') #changes the markers from circles to green diamonds
plt.boxplot(dataframes, flierprops=green_diamond)
plt.show()

# %% [markdown]
# # Iris Data Set - Box Plot
# Being familiar with the Iris dataset, I feel is it an ideal data set to use to generate box plots

# %%
#ref: https://github.com/ClaireDrummond/GMITProject2018

import pandas # library for statistics in data anaylsis

# Load dataset from UCI Machine Learning repository - new learning
iris_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
dataset = pandas.read_csv(iris_url, names=names)

# shape - this tells quantity of rows and columns in the dataset
print(dataset.shape)

# head - prints first ten rows of the dataset
print(dataset.head(10))

# description - prints keys stats on the dataset
print(dataset.describe())
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# ...

# %%
dataset.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
plt.boxplot(dataset.sepal_length)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bda8580fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bda858a8d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bda8580e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bda8592160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bda8592588>],
#  'means': []}

# %%
plt.boxplot(dataset.sepal_width)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bda85dfac8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bda85ea358>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bda85df978>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bda85eaba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bda85eafd0>],
#  'means': []}

# %%
plt.boxplot(dataset.petal_length)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bda8636e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bda863f780>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bda8636d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bda863ffd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bda8649438>],
#  'means': []}

# %%
plt.boxplot(dataset.petal_width)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bda9668470>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bda9668d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bda9668320>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bda96715c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bda96719e8>],
#  'means': []}

# %%
# generate the 4 boxplots together in one line of code
# ref:https://matplotlib.org/gallery/recipes/create_subplots.html
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False) 
plt.show()

# %% [markdown]
# # Terminology
#
# Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
#
# median (Q2/50th Percentile): the middle value of the dataset.
#
# first quartile (Q1/25th Percentile): the middle number between the smallest number (not the “minimum”) and the median of the dataset.
#
# third quartile (Q3/75th Percentile): the middle value between the median and the highest value (not the “maximum”) of the dataset.
#
# interquartile range (IQR): 25th to the 75th percentile.
#
# whiskers (shown in blue)
#
# outliers (shown as green circles)
#
# “maximum”: Q3 + 1.5*IQR
#
# “minimum”: Q1 -1.5*IQR

# %% [markdown]
# ![Terminology.PNG](attachment:Terminology.PNG)

# %% [markdown]
# #### above diagram ref: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
